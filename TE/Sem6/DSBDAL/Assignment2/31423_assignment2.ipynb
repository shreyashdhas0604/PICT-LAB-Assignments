# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('StudentPerformance.csv')

# %%
df
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         62.0             88           60.0               95            2020
# 1         62.0             95           76.0               76            2021
# 2         69.0             84           69.0               86            2018
# 3         64.0             90           80.0               80            2019
# 4         78.0             90           76.0              100            2018
# 5         68.0             80           76.0               91            2020
# 6         77.0             80           77.0               92            2019
# 7         79.0             89           61.0               87            2021
# 8         69.0             86           74.0               98            2020
# 9         76.0             91           66.0               77            2021
# 10        66.0             83           62.0               90            2019
# ...

# %%
df.isnull()
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False          False          False            False           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
series = pd.isnull(df["writing score"])

# %%
df[series]
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 23        78.0             80            NaN               85            2021
# 26         NaN             91            NaN               94            2019
#
#     placement offer count  gender
# 23                      3  Female
# 26                      3  Female

# %%
df.notnull()
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6         True           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
series1 = pd.notnull(df["math score"])

# %%
df[series1]
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         62.0             88           60.0               95            2020
# 1         62.0             95           76.0               76            2021
# 2         69.0             84           69.0               86            2018
# 3         64.0             90           80.0               80            2019
# 4         78.0             90           76.0              100            2018
# 5         68.0             80           76.0               91            2020
# 6         77.0             80           77.0               92            2019
# 7         79.0             89           61.0               87            2021
# 8         69.0             86           74.0               98            2020
# 9         76.0             91           66.0               77            2021
# 10        66.0             83           62.0               90            2019
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['gender'] = le.fit_transform(df['gender'])
newdf=df

# %%
df
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         62.0             88           60.0               95            2020
# 1         62.0             95           76.0               76            2021
# 2         69.0             84           69.0               86            2018
# 3         64.0             90           80.0               80            2019
# 4         78.0             90           76.0              100            2018
# 5         68.0             80           76.0               91            2020
# 6         77.0             80           77.0               92            2019
# 7         79.0             89           61.0               87            2021
# 8         69.0             86           74.0               98            2020
# 9         76.0             91           66.0               77            2021
# 10        66.0             83           62.0               90            2019
# ...

# %%
newdf
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         62.0             88           60.0               95            2020
# 1         62.0             95           76.0               76            2021
# 2         69.0             84           69.0               86            2018
# 3         64.0             90           80.0               80            2019
# 4         78.0             90           76.0              100            2018
# 5         68.0             80           76.0               91            2020
# 6         77.0             80           77.0               92            2019
# 7         79.0             89           61.0               87            2021
# 8         69.0             86           74.0               98            2020
# 9         76.0             91           66.0               77            2021
# 10        66.0             83           62.0               90            2019
# ...

# %%
newdf["math score"] = newdf["math score"].fillna(newdf["math score"].min())

# %%
newdf
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         62.0             88           60.0               95            2020
# 1         62.0             95           76.0               76            2021
# 2         69.0             84           69.0               86            2018
# 3         64.0             90           80.0               80            2019
# 4         78.0             90           76.0              100            2018
# 5         68.0             80           76.0               91            2020
# 6         77.0             80           77.0               92            2019
# 7         79.0             89           61.0               87            2021
# 8         69.0             86           74.0               98            2020
# 9         76.0             91           66.0               77            2021
# 10        66.0             83           62.0               90            2019
# ...

# %%
col = ['math score','reading score','writing score','placement score']

# %%
# !pip install seaborn
import seaborn as sns
sns.boxplot(data = newdf,x = 'math score')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# <Axes: xlabel='math score'>

# %%
print(np.where(newdf['math score'] > 90))
# Out:
# (array([19]),)

# %%
newdf
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         62.0             88           60.0               95            2020
# 1         62.0             95           76.0               76            2021
# 2         69.0             84           69.0               86            2018
# 3         64.0             90           80.0               80            2019
# 4         78.0             90           76.0              100            2018
# 5         68.0             80           76.0               91            2020
# 6         77.0             80           77.0               92            2019
# 7         79.0             89           61.0               87            2021
# 8         69.0             86           74.0               98            2020
# 9         76.0             91           66.0               77            2021
# 10        66.0             83           62.0               90            2019
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize = (18,10))

# %%
ax.scatter(df['placement score'], df['placement offer count'])

# %%
plt.show()

# %%
print(np.where((df['placement score']<50) & (df['placement offer count']>1)))
# Out:
# (array([], dtype=int64),)

# %%
print(np.where((df['placement score']>85) & (df['placement offer count']<3)))
# Out:
# (array([20]),)

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df['math score']))

# %%
print(z)
# Out:
# 0     0.820997
# 1     0.820997
# 2     0.029321
# 3     0.578049
# 4     1.122588
# 5     0.092153
# 6     1.001114
# 7     1.244062
# 8     0.029321
# 9     0.879640
# 10    0.335101
# 11    1.365536
# 12    0.393743
# 13    0.820997
# 14    0.456575
# 15    1.122588
# 16    0.456575
# 17    0.029321
# 18    0.942471
# 19    3.187646
# 20    0.029321
# 21    0.942471
# 22    0.942471
# 23    1.122588
# 24    1.063945
# 25    0.335101
# 26    1.063945
# 27    0.942471
# 28    0.942471
# Name: math score, dtype: float64

# %%
threshold = 0.18
sample_outliers = np.where(z <threshold)
sample_outliers
# Out:
# (array([ 2,  5,  8, 17, 20]),)

# %%
sorted_rscore= sorted(df['reading score'])
sorted_rscore
# Out:
# [75,
#  75,
#  75,
#  77,
#  77,
#  78,
#  79,
#  80,
#  80,
#  80,
#  80,
#  80,
#  82,
#  83,
#  83,
#  83,
#  84,
#  86,
#  88,
#  89,
#  90,
#  90,
#  90,
#  91,
#  91,
#  93,
#  93,
#  94,
#  95]

# %%
q1 = np.percentile(sorted_rscore, 25)

# %%
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# 80.0 90.0

# %%
IQR = q3-q1
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 65.0 105.0

# %%
r_outliers = []
for i in sorted_rscore:
    if (i<lwr_bound or i>upr_bound):
        r_outliers.append(i)
print(r_outliers)
# Out:
# []

# %%
newdf = df

# %%
print(newdf.index)
# Out:
# RangeIndex(start=0, stop=29, step=1)

# %%
print(sample_outliers)
# Out:
# (array([ 2,  5,  8, 17, 20]),)

# %%
col = ['reading score']
df.boxplot(col)
# Out:
# <Axes: >
